# %% [markdown]
# 02-10-23 | Feature request for native Screen Recording in Omniverse.

# %% [markdown]
# Re: Video Screen Recording Option.
# One of the most amazing aspects of Omniverse is connecting everything together. Apps 2 Apps, People to People. There is a ton to learn and to share.
# Right now, making tutorials to help others is a fairly cumbersome process. We also see users, in Discord, documenting their Omni difficulties using cell phones to video their PC screens. In 2023, a cell phone should not be the easiest way for our users to document their screens.
# This is the same problem the Modo community faced in its early days. To help someone either required attempting to do so with text, or making a full video. The first was often inadequate for the receiver, but making an explainer video was cumbersome for the giver.
# To this day, getting the right screen capture software, plus one that displays keystrokes etc. requires a commitment and isn't a 'one-off'.
# "Hey, I'd love to help you, but I only can use text to explain what you need to do graphically."
# In addition, there are no production standards. I might send cropped graphics, or badly taken phone footage to you from any number of platforms you may or may not have access to.
#  Yet peer to peer transmission of knowledge is one of the best ways for Omniverse to grow and its "virability" depends on accessibility.
# Thus I would ask, Omni's great Dev's if there is a way to make sharing knowledge through screen recordings more accessible?
# - Could there be a 'Record Screen w/video' option in Omniverse?
# - If there was a parameter that I could check to include 'display key strokes', that would be amazing.
# - The ability to zoom into part of the screen - that is pro level that I rarely see, but always appreciate on the receiver side.
# Screen recordings are 'ground truth' for helping others.
# "Oh, he clicked there.. the layer is is a sub layer..." etc. Those are the details that are captured in screen recordings that are remiss in text chats and are often cumbersome to capture with stills.
# Please help us grow Omniverse, by making 'Screen Recordings' more accessible. It could just be a dropdown menu.
#
# Imagine if, late at night, you post the problem you are having with Omniverse, and you wake up on the morning and find a notification in the launcher that displays an explainer video that I made for you that helps you with your exact problem.
# No 3d platform in the world currently offers that level of support or peer-peer sharing of knowledge.
# Thanks for your time, and striving to make the impossible, possible.
#
# Cheers,
#
# -Zia

# %% [markdown]
# In Machinima, UI obscures its own elements, the window (x) makes accessing the playhead difficult and adds the risk of closing the timeline instead of selecting the playhead:
# ![Playhead%20is%20obscured%20by%20window%20elements%20and%20x.jpg](attachment:Playhead%20is%20obscured%20by%20window%20elements%20and%20x.jpg)

# %% [markdown]
# ![timeline-what%20is%20this%20called-QUESTION.jpg](attachment:timeline-what%20is%20this%20called-QUESTION.jpg)

# %% [markdown]
# It is unusual that the timeline extends below zero, but the user does not know that. So I can make my playhead invisible.
# ![I%20can%20walk%20playhead%20out%20of%20visible%20range.gif](attachment:I%20can%20walk%20playhead%20out%20of%20visible%20range.gif)

# %% [markdown]
# In the Curve Editor, pressing the Left Arrow and Right Arrow keys doesn't not affect the playhead.
# ![Curve%20Editor%20Arrow%20Keys%20on%20Keyboard%20should%20walk%20forward%20and%20backward%20from%20by%20frame..jpg](attachment:Curve%20Editor%20Arrow%20Keys%20on%20Keyboard%20should%20walk%20forward%20and%20backward%20from%20by%20frame..jpg)

# %% [markdown]
# rmb to set a key produces different results for each component channel:
#
# ![rmb%20to%20set%20a%20key%20produces%20different%20results%20for%20each%20component%20channel.gif](attachment:rmb%20to%20set%20a%20key%20produces%20different%20results%20for%20each%20component%20channel.gif)

# %% [markdown]
# The upper bar of this panel is clipped and cannot be moved with mmb or dragged. It should slide.
# ![Menu%20is%20Clipped%20but%20does%20not%20slide%20as%20needed.gif](attachment:Menu%20is%20Clipped%20but%20does%20not%20slide%20as%20needed.gif)

# %% [markdown]
# A single or double click in the graph area should bring the playhead to the cursor. I should not have to use the cursor to go and chase the play head.

# %% [markdown]
# Layouts doesn't save a Layout.JSON file.

# %% [markdown]
# [root] > Animation > Curve Editor = Just flashes to screen. Does not work.

# %% [markdown]
# Creating a![Camera%20two%20has%20same%20name%20as%20Camera%201%20instead%20of%20%20being%20Camera%202.jpg](attachment:Camera%20two%20has%20same%20name%20as%20Camera%201%20instead%20of%20%20being%20Camera%202.jpg) second camera does not create a name of 'Camera 2'. I cannot change the name the layer menu nor in the property window. Only in the Stage Window.

# %% [markdown]
# ![Why%20are%20locks%20here%20instead%20of%20at%20layer%20level.jpg](attachment:Why%20are%20locks%20here%20instead%20of%20at%20layer%20level.jpg)

# %% [markdown]
# ![locks%20should%20be%20here..jpg](attachment:locks%20should%20be%20here..jpg)

# %% [markdown]
# From the Light Buld example, I wish I could name the backdrops directly for the sake of Clarity.
# ![Name%20Background%20Reverts%20Light%20Switch%20Example.gif](attachment:Name%20Background%20Reverts%20Light%20Switch%20Example.gif)

# %% [markdown]
# So it would be cool is we didn't have to use Snake_Case to name backdrops.. or if we get an error that tells us what we need to do:
# ![Snake_Case_Needed_for_Backdrop_Naming.gif](attachment:Snake_Case_Needed_for_Backdrop_Naming.gif)

# %% [markdown]
# The gray checkmarks are very hard to read, especially for a live stream. Lets just use a regular fill value for the box instead of check mark.
# ![Grey%20Check%20Mark%20for%20Value%20is%20Hard%20to%20Read.jpg](attachment:Grey%20Check%20Mark%20for%20Value%20is%20Hard%20to%20Read.jpg)

# %% [markdown]
# Under Omni-code, extensions, clicking on the [gear] icon does trigger the 'file explorer' window to pop up.
# ![I_wish_Open_Button_Triggered_File_Explorer.gif](attachment:I_wish_Open_Button_Triggered_File_Explorer.gif)
